# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\devan\OneDrive\Attachments\Desktop\Startup Success Prediction app\dirty_startup_50k.csv")

# %%
data
# Out:
#         startup_name   industry  funding  founder_experience  employees  \
# 0          Startup_0    Fintech      NaN                 NaN        NaN
# 1          Startup_1    Fintech      NaN                 NaN      126.0
# 2          Startup_2     Edtech      NaN                 4.0        NaN
# 3          Startup_3     Health      NaN                 2.0        NaN
# 4          Startup_4    Fintech      NaN                 NaN      196.0
# ...              ...        ...      ...                 ...        ...
# 49995  Startup_49995  CleanTech      NaN                 NaN        NaN
# 49996  Startup_49996  CleanTech      abc                 2.0        NaN
# 49997  Startup_49997    Fintech      NaN                15.0        NaN
# 49998  Startup_49998  CleanTech      NaN                12.0      384.0
# 49999  Startup_49999     Edtech  1241594                 8.0       72.0
#
#       location   age   revenue  success
# 0          USA   NaN  130268.0        0
# ...

# %% [markdown]
# # Data Cleaning

# %%
data.head()
# Out:
#   startup_name industry funding  founder_experience  employees location   age  \
# 0    Startup_0  Fintech     NaN                 NaN        NaN      USA   NaN
# 1    Startup_1  Fintech     NaN                 NaN      126.0    India   NaN
# 2    Startup_2   Edtech     NaN                 4.0        NaN    India   NaN
# 3    Startup_3   Health     NaN                 2.0        NaN       UK  12.0
# 4    Startup_4  Fintech     NaN                 NaN      196.0   Canada   NaN
#
#     revenue  success
# 0  130268.0        0
# 1  541430.0        1
# 2       NaN        1
# 3       NaN        0
# 4  255796.0        0

# %%
data.shape
# Out:
# (50000, 9)

# %%
data.columns
# Out:
# Index(['startup_name', 'industry', 'funding', 'founder_experience',
#        'employees', 'location', 'age', 'revenue', 'success'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# startup_name              0
# industry                  0
# funding               25038
# founder_experience    24881
# employees             25149
# location               8156
# age                   25027
# revenue               25039
# success                   0
# dtype: int64

# %%
data['funding'] = pd.to_numeric(data['funding'], errors='coerce')

# %%
data['funding'] = data['funding'].fillna(1000000)

# %%
data
# Out:
#         startup_name   industry    funding  founder_experience  employees  \
# 0          Startup_0    Fintech  1000000.0                 NaN        NaN
# 1          Startup_1    Fintech  1000000.0                 NaN      126.0
# 2          Startup_2     Edtech  1000000.0                 4.0        NaN
# 3          Startup_3     Health  1000000.0                 2.0        NaN
# 4          Startup_4    Fintech  1000000.0                 NaN      196.0
# ...              ...        ...        ...                 ...        ...
# 49995  Startup_49995  CleanTech  1000000.0                 NaN        NaN
# 49996  Startup_49996  CleanTech  1000000.0                 2.0        NaN
# 49997  Startup_49997    Fintech  1000000.0                15.0        NaN
# 49998  Startup_49998  CleanTech  1000000.0                12.0      384.0
# 49999  Startup_49999     Edtech  1241594.0                 8.0       72.0
#
#       location   age   revenue  success
# ...

# %%
data.isnull().sum()
# Out:
# startup_name              0
# industry                  0
# funding                   0
# founder_experience    24881
# employees             25149
# location               8156
# age                   25027
# revenue               25039
# success                   0
# dtype: int64

# %%
data['founder_experience'] = data['founder_experience'].fillna(14)

# %%
data
# Out:
#         startup_name   industry    funding  founder_experience  employees  \
# 0          Startup_0    Fintech  1000000.0                14.0        NaN
# 1          Startup_1    Fintech  1000000.0                14.0      126.0
# 2          Startup_2     Edtech  1000000.0                 4.0        NaN
# 3          Startup_3     Health  1000000.0                 2.0        NaN
# 4          Startup_4    Fintech  1000000.0                14.0      196.0
# ...              ...        ...        ...                 ...        ...
# 49995  Startup_49995  CleanTech  1000000.0                14.0        NaN
# 49996  Startup_49996  CleanTech  1000000.0                 2.0        NaN
# 49997  Startup_49997    Fintech  1000000.0                15.0        NaN
# 49998  Startup_49998  CleanTech  1000000.0                12.0      384.0
# 49999  Startup_49999     Edtech  1241594.0                 8.0       72.0
#
#       location   age   revenue  success
# ...

# %%
data['employees'] = data['employees'].fillna(350)

# %%
data
# Out:
#         startup_name   industry    funding  founder_experience  employees  \
# 0          Startup_0    Fintech  1000000.0                14.0      350.0
# 1          Startup_1    Fintech  1000000.0                14.0      126.0
# 2          Startup_2     Edtech  1000000.0                 4.0      350.0
# 3          Startup_3     Health  1000000.0                 2.0      350.0
# 4          Startup_4    Fintech  1000000.0                14.0      196.0
# ...              ...        ...        ...                 ...        ...
# 49995  Startup_49995  CleanTech  1000000.0                14.0      350.0
# 49996  Startup_49996  CleanTech  1000000.0                 2.0      350.0
# 49997  Startup_49997    Fintech  1000000.0                15.0      350.0
# 49998  Startup_49998  CleanTech  1000000.0                12.0      384.0
# 49999  Startup_49999     Edtech  1241594.0                 8.0       72.0
#
#       location   age   revenue  success
# ...

# %%
data.isnull().sum()
# Out:
# startup_name              0
# industry                  0
# funding                   0
# founder_experience        0
# employees                 0
# location               8156
# age                   25027
# revenue               25039
# success                   0
# dtype: int64

# %%
data['location'] = data['location'].fillna('India')
data['age'] = data['age'].fillna(9)
data['revenue'] = data['revenue'].fillna(510400)

# %%
data
# Out:
#         startup_name   industry    funding  founder_experience  employees  \
# 0          Startup_0    Fintech  1000000.0                14.0      350.0
# 1          Startup_1    Fintech  1000000.0                14.0      126.0
# 2          Startup_2     Edtech  1000000.0                 4.0      350.0
# 3          Startup_3     Health  1000000.0                 2.0      350.0
# 4          Startup_4    Fintech  1000000.0                14.0      196.0
# ...              ...        ...        ...                 ...        ...
# 49995  Startup_49995  CleanTech  1000000.0                14.0      350.0
# 49996  Startup_49996  CleanTech  1000000.0                 2.0      350.0
# 49997  Startup_49997    Fintech  1000000.0                15.0      350.0
# 49998  Startup_49998  CleanTech  1000000.0                12.0      384.0
# 49999  Startup_49999     Edtech  1241594.0                 8.0       72.0
#
#       location   age   revenue  success
# ...

# %%
data.isnull().sum()
# Out:
# startup_name          0
# industry              0
# funding               0
# founder_experience    0
# employees             0
# location              0
# age                   0
# revenue               0
# success               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#             funding  founder_experience     employees           age  \
# count  5.000000e+04        50000.000000  50000.000000  50000.000000
# mean   1.004115e+06           12.005880    300.774100      8.260880
# std    2.813879e+05            4.366251    112.188394      2.949487
# min    5.042200e+04            1.000000      5.000000      1.000000
# 25%    1.000000e+06           10.000000    252.000000      8.000000
# 50%    1.000000e+06           14.000000    350.000000      9.000000
# 75%    1.000000e+06           14.000000    350.000000      9.000000
# max    1.999961e+06           19.000000    499.000000     14.000000
#
#              revenue       success
# count   50000.000000  50000.000000
# mean   510400.051040      0.499360
# std    199999.594685      0.500005
# min     20013.000000      0.000000
# 25%    510400.000000      0.000000
# 50%    510400.000000      0.000000
# 75%    511490.500000      1.000000
# max    999941.000000      1.000000

# %%
data
# Out:
#         startup_name   industry    funding  founder_experience  employees  \
# 0          Startup_0    Fintech  1000000.0                14.0      350.0
# 1          Startup_1    Fintech  1000000.0                14.0      126.0
# 2          Startup_2     Edtech  1000000.0                 4.0      350.0
# 3          Startup_3     Health  1000000.0                 2.0      350.0
# 4          Startup_4    Fintech  1000000.0                14.0      196.0
# ...              ...        ...        ...                 ...        ...
# 49995  Startup_49995  CleanTech  1000000.0                14.0      350.0
# 49996  Startup_49996  CleanTech  1000000.0                 2.0      350.0
# 49997  Startup_49997    Fintech  1000000.0                15.0      350.0
# 49998  Startup_49998  CleanTech  1000000.0                12.0      384.0
# 49999  Startup_49999     Edtech  1241594.0                 8.0       72.0
#
#       location   age   revenue  success
# ...

# %%
pip install psycopg2_binary sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

# step 1: Connect to Postgresql
# Replace placeholders with your actual details
username = "postgres"
password = "MANDIRps%406"        # here the only @ is converted in %40 because jupyter cannot take the @ like symbols 
host = 'localhost'               # so we caonverted @ into %40 and other code is same as it is
port = "5433"
database = "Startup_database"

engine = create_engine('postgresql://postgres:MANDIRps%406@localhost:5433/Startup_database')

 


# step 2 Load dataframe into Postgresql
table_name = "startup"
data.to_sql(table_name, engine,if_exists="replace", index=False)

print(f"Data successfully loaded into table'{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table'startup' in database 'Startup_database'.

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.countplot( data = data , x = 'industry' , hue  = 'success' )
# Out:
# <Axes: xlabel='industry', ylabel='count'>

# %% [raw]
# Fintech has the most success rate than others

# %%
sns.countplot(data = data , x = 'location' , hue = 'success')
# Out:
# <Axes: xlabel='location', ylabel='count'>

# %%
sns.violinplot(data = data , x = 'success' , y = 'employees' )
# Out:
# <Axes: xlabel='success', ylabel='employees'>

# %%
sns.boxplot(data = data , x = 'success' , y = 'founder_experience')
# Out:
# <Axes: xlabel='success', ylabel='founder_experience'>

# %%
sns.heatmap(data.corr(numeric_only=True),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # Data Preprocessing and Data Cleaning

# %%
data = pd.read_excel(r"C:\Users\devan\OneDrive\Attachments\Desktop\Startup Success Prediction app\output_2.xlsx")

# %%
data
# Out:
#        Unnamed: 0   startup_name   industry  funding  founder_experience  \
# 0               0      Startup_0    Fintech  1000000                  14
# 1               1      Startup_1    Fintech  1000000                  14
# 2               2      Startup_2     Edtech  1000000                   4
# 3               3      Startup_3     Health  1000000                   2
# 4               4      Startup_4    Fintech  1000000                  14
# ...           ...            ...        ...      ...                 ...
# 49995       49995  Startup_49995  CleanTech  1000000                  14
# 49996       49996  Startup_49996  CleanTech  1000000                   2
# 49997       49997  Startup_49997    Fintech  1000000                  15
# 49998       49998  Startup_49998  CleanTech  1000000                  12
# 49999       49999  Startup_49999     Edtech  1241594                   8
#
#        employees location  age  revenue  success
# ...

# %%
data = data.drop(['Unnamed: 0','startup_name'], axis = 1)

# %%
data
# Out:
#         industry  funding  founder_experience  employees location  age  \
# 0        Fintech  1000000                  14        350      USA    9
# 1        Fintech  1000000                  14        126    India    9
# 2         Edtech  1000000                   4        350    India    9
# 3         Health  1000000                   2        350       UK   12
# 4        Fintech  1000000                  14        196   Canada    9
# ...          ...      ...                 ...        ...      ...  ...
# 49995  CleanTech  1000000                  14        350   Canada    9
# 49996  CleanTech  1000000                   2        350       UK    7
# 49997    Fintech  1000000                  15        350    India   14
# 49998  CleanTech  1000000                  12        384  Germany    7
# 49999     Edtech  1241594                   8         72   Canada   14
#
#        revenue  success
# 0       130268        0
# 1       541430        1
# 2       510400        1
# ...

# %%
x = data.drop(columns = ['success'],axis = 1 )
y = data['success']

# %%
x.columns
# Out:
# Index(['industry', 'funding', 'founder_experience', 'employees', 'location',
#        'age', 'revenue'],
#       dtype='object')

# %%
x_one_encode = pd.get_dummies(x,columns = ['industry','location'],drop_first = True)

# %%
x_one_encode
# Out:
#        funding  founder_experience  employees  age  revenue  \
# 0      1000000                  14        350    9   130268
# 1      1000000                  14        126    9   541430
# 2      1000000                   4        350    9   510400
# 3      1000000                   2        350   12   510400
# 4      1000000                  14        196    9   255796
# ...        ...                 ...        ...  ...      ...
# 49995  1000000                  14        350    9   510400
# 49996  1000000                   2        350    7    24612
# 49997  1000000                  15        350   14   510400
# 49998  1000000                  12        384    7   268860
# 49999  1241594                   8         72   14   510400
#
#        industry_CleanTech  industry_Ecommerce  industry_Edtech  \
# 0                   False               False            False
# 1                   False               False            False
# ...

# %%
print(x_one_encode.dtypes)
# Out:
# funding               int64
# founder_experience    int64
# employees             int64
# age                   int64
# revenue               int64
# industry_CleanTech     bool
# industry_Ecommerce     bool
# industry_Edtech        bool
# industry_Fintech       bool
# industry_Health        bool
# location_Germany       bool
# location_India         bool
# location_UK            bool
# location_USA           bool
# dtype: object

# %%
x_one_encode = x_one_encode.astype(int)

# %%
x_one_encode
# Out:
#        funding  founder_experience  employees  age  revenue  \
# 0      1000000                  14        350    9   130268
# 1      1000000                  14        126    9   541430
# 2      1000000                   4        350    9   510400
# 3      1000000                   2        350   12   510400
# 4      1000000                  14        196    9   255796
# ...        ...                 ...        ...  ...      ...
# 49995  1000000                  14        350    9   510400
# 49996  1000000                   2        350    7    24612
# 49997  1000000                  15        350   14   510400
# 49998  1000000                  12        384    7   268860
# 49999  1241594                   8         72   14   510400
#
#        industry_CleanTech  industry_Ecommerce  industry_Edtech  \
# 0                       0                   0                0
# 1                       0                   0                0
# ...

# %%
from sklearn.preprocessing import StandardScaler


numerical_columns = ['funding','founder_experience','employees','age','revenue']       # scaling between -3 to 3 
scaler = StandardScaler()

x_one_encode[numerical_columns] = scaler.fit_transform(x_one_encode[numerical_columns])

# %%
x_one_encode
# Out:
#         funding  founder_experience  employees       age       revenue  \
# 0     -0.014624            0.456717   0.438783  0.250595 -1.900683e+00
# 1     -0.014624            0.456717  -1.557878  0.250595  1.551516e-01
# 2     -0.014624           -1.833601   0.438783  0.250595 -2.552031e-07
# 3     -0.014624           -2.291664   0.438783  1.267731 -2.552031e-07
# 4     -0.014624            0.456717  -0.933921  0.250595 -1.273036e+00
# ...         ...                 ...        ...       ...           ...
# 49995 -0.014624            0.456717   0.438783  0.250595 -2.552031e-07
# 49996 -0.014624           -2.291664   0.438783 -0.427496 -2.428969e+00
# 49997 -0.014624            0.685748   0.438783  1.945822 -2.552031e-07
# 49998 -0.014624           -0.001347   0.741848 -0.427496 -1.207715e+00
# 49999  0.843964           -0.917474  -2.039216  1.945822 -2.552031e-07
#
#        industry_CleanTech  industry_Ecommerce  industry_Edtech  \
# ...

# %%
print(x_one_encode.dtypes)
# Out:
# funding               float64
# founder_experience    float64
# employees             float64
# age                   float64
# revenue               float64
# industry_CleanTech      int64
# industry_Ecommerce      int64
# industry_Edtech         int64
# industry_Fintech        int64
# industry_Health         int64
# location_Germany        int64
# location_India          int64
# location_UK             int64
# location_USA            int64
# dtype: object

# %% [markdown]
# # Model Evaluating

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
print(X_train.dtypes)
# Out:
# industry              object
# funding                int64
# founder_experience     int64
# employees              int64
# location              object
# age                    int64
# revenue                int64
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([1, 0, 1, ..., 1, 0, 0], shape=(10000,))

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5072

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[3170, 1831],
#        [3112, 1887]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.63      0.56      5001
#            1       0.51      0.38      0.43      4999
#
#     accuracy                           0.51     10000
#    macro avg       0.51      0.51      0.50     10000
# weighted avg       0.51      0.51      0.50     10000

# %% [markdown]
# # Joblib
